# %% [markdown]
# # DS-SF-32 | Homework 02: The `pandas` Library

# %% [markdown]
# In this homework, we will be exploring the `police shootings` dataset using `pandas`.

# %%
import pandas as pd

# %%
killings = pd.read_csv('/Users/Kevin/Desktop/Data_Science_Repository/DS-SF-32/dataset/police-killings.csv')
killings.shape
# Out:
# (467, 15)

# %% [markdown]
# #### A) Starter question: Display a few lines of the dataset to the screen.

# %%
df = killings.copy()
df.head()
# Out:
#    Unnamed: 0                name  age gender    raceethnicity     month  day  \
# 0           0  A'donte Washington   16   Male            Black  February   23
# 1           1      Aaron Rutledge   27   Male            White     April    2
# 2           2         Aaron Siler   26   Male            White     March   14
# 3           3        Aaron Valdez   25   Male  Hispanic/Latino     March   11
# 4           4        Adam Jovicic   29   Male            White     March   19
#
#    year           streetaddress          city state  \
# 0  2015            Clearview Ln     Millbrook    AL
# 1  2015  300 block Iris Park Dr     Pineville    LA
# 2  2015    22nd Ave and 56th St       Kenosha    WI
# 3  2015       3000 Seminole Ave    South Gate    CA
# 4  2015          364 Hiwood Ave  Munroe Falls    OH
#
#               lawenforcementagency    cause    armed  county_income
# 0      Millbrook Police Department  Gunshot       No          54766
# ...

# %% [markdown]
# #### 1. Make the following changed to column names:
#
# + lawenforcementagency -> agency
# + raceethnicity        -> race

# %%
df.rename(columns={"lawenforcementagency":"agency" , "raceethnicity":"race"},inplace= True)
df
# Out:
#      Unnamed: 0                     name  age  gender             race  \
# 0             0                    hello   16    Male            Black
# 1             1           Aaron Rutledge   27    Male            White
# 2             2              Aaron Siler   26    Male            White
# 3             3             Aaron Valdez   25    Male  Hispanic/Latino
# 4             4             Adam Jovicic   29    Male            White
# 5             5            Adam Reinhart   29    Male            White
# 6             6         Adrian Hernandez   22    Male  Hispanic/Latino
# 7             7             Adrian Solis   35    Male  Hispanic/Latino
# 8             8            Alan Alverson   44    Male            White
# 9             9               Alan James   31    Male            White
# 10           10         Albert Hanson Jr   76    Male            White
# 11           11           Alec Ouzounian   40    Male            White
# ...

# %% [markdown]
# #### 2. Show the count of missing values in each column

# %%
df.isnull().sum()
#There are 4 missing street addresses, that's it
# Out:
# Unnamed: 0       0
# name             0
# age              0
# gender           0
# race             0
# month            0
# day              0
# year             0
# streetaddress    4
# city             0
# state            0
# agency           0
# cause            0
# armed            0
# county_income    0
# dtype: int64

# %% [markdown]
# #### 3. replace each null value in the dataframe with the string "Unknown"

# %%
#df[df["streetaddress"].isnull()]
df.fillna("Unknown",inplace=True)
df[df["streetaddress"] == "Unknown"]
# Out:
#      Unnamed: 0                             name  age gender             race  \
# 50           50                    Billy Patrick   29   Male            White
# 280         280                    Kenneth Brown   18   Male            White
# 379         379                       Ricky Hall   27   Male            Black
# 405         405  Santos 'Cuate' Cortez Hernandez   24   Male  Hispanic/Latino
#
#        month  day  year streetaddress        city state  \
# 50     April   26  2015       Unknown       Bunch    OK
# 280  January    4  2015       Unknown     Guthrie    OK
# 379    March   30  2015       Unknown  Fort Meade    MD
# 405    April   20  2015       Unknown     Mission    TX
#
#                                            agency    cause  \
# 50   Oklahoma Department of Wildlife Conservation  Gunshot
# 280                         Oklahoma State Police  Gunshot
# 379                         NSA Police Department  Gunshot
# ...

# %% [markdown]
# #### 4. How many killings were there so far in 2015?

# %%
df[df["year"] == 2015].count()
#all killings have taken place in 2015, so 467
print "467 killings have taken place in 2015.  All the killings are in 2015"
# Out:
# 467 killings have taken place in 2015.  All the killins are in 2015

# %% [markdown]
# #### 5. Of all killings, how many were male and how many female?

# %%
male = df[df["gender"]== "Male"].shape[0]
female = df[df["gender"]== "Female"].shape[0]
print "Male killings = %d, Female killings = %d" % (male,female)
# Out:
# Male killings = 445, Female killings = 22

# %% [markdown]
# #### 6. How many killings were of unarmed people?

# %%
unarmed = df[df["armed"] == "No"].shape[0]
unarmed
# Out:
# 102

# %% [markdown]
# #### 7. What percentage of all killings were unarmed?

# %%
102.0 / 467 * 100
# Out:
# 21.841541755888652

# %% [markdown]
# #### 8. What are the 5 states with the most killings?

# %% [markdown]
# #### 9. Show a value counts of deaths for each race

# %% [markdown]
# #### 10. Display a histogram of ages of all killings

# %% [markdown]
# #### 11. Show 6 histograms of ages by race

# %% [markdown]
# #### 12. What is the average age of death by race?

# %% [markdown]
# #### 13. Show a bar chart with counts of deaths every month
